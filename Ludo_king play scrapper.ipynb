# %% [markdown]
# ![images.jpeg](attachment:images.jpeg)

# %%
pip install google_play_scraper

# %%
from google_play_scraper import app
result=app("com.ludo.king",
          lang="en",country="us")

# %%
print(result)
# Out:
# {'title': 'Ludo King®', 'description': "*THIS IS OFFICIAL LUDO KING® GAME\r\n\r\n<b>1 Billion+ Downloads!</b>\r\n\r\n<b>Voice chat available.</b>\r\n\r\n<b>Most popular Ludo game. A first Ludo game of its kind available on mobile since 2016!</b>\r\n\r\nLudo King® is a classic board game played between friends and family. Play the dice game of kings! Recall your childhood! In some places, Ludo is also known as Parchisi, Pachisi, parcheesi or Parchisi game.\r\n\r\nLudo King is a cross platform multiplayer game that supports Desktop, Android, iOS, HTML5 and Windows mobile platform at same time. This game also support offline mode, where player can play with Computer or, Local multiplayer (pass and play mode). Play this dice game Ludo King. Best casual game in board games.\r\n\r\n<b>New Game Themes available:</b>\r\nDisco / Night mode Theme\r\nNature Theme\r\nEgypt Theme\r\nPinball Theme\r\nCandy Theme\r\nChristmas Theme\r\nPenguin Theme\r\nBattle Theme\r\nDiwali Theme\r\nPirate Theme\r\
# ...

# %%
from google_play_scraper import Sort,reviews
result,continuation_token=reviews(
'com.ludo.king',
lang='en',
country='us',
sort=Sort.NEWEST,
count=1000,
filter_score_with=5)
result,_=reviews('com.ludo.king',
                continuation_token=continuation_token)

# %%
print(result)
# Out:
# [{'reviewId': '9a9ecfcb-cc49-4025-b325-a9a6b30cbd6c', 'userName': 'Sonusingh Rajput', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUFmo-CkCJcWGvBgSDWpHYTgGtA9BKt9p0cREwOd3_KR0Etv_8', 'content': '👍👍👍', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2024, 8, 6, 16, 38, 2), 'replyContent': None, 'repliedAt': None, 'appVersion': None}, {'reviewId': 'e3f5fa7e-8d82-4d88-a821-f65a50d2a154', 'userName': 'Ahamed Thameez', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIpVl0Ib60TlOg62ZF8ln6uBCaeMpElTfnjzdXHpvr8gwn7jQ=mo', 'content': 'Good', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '8.7.0.297', 'at': datetime.datetime(2024, 8, 6, 16, 19, 24), 'replyContent': 'Thank you so much! Ahamed :)', 'repliedAt': datetime.datetime(2024, 8, 7, 11, 30, 49), 'appVersion': '8.7.0.297'}, {'reviewId': 'da0298b8-f353-4902-b133-23c20e5e7ee3', 'userName': 'atilla', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKaYYQUQp
# ...

# %%
import pandas as pd
import numpy as np

# %%
ludo=pd.DataFrame(np.array(result),columns=['review'])
ludo=ludo.join(pd.DataFrame(ludo.pop('review').tolist()))
ludo.head()
# Out:
#                                reviewId          userName  \
# 0  9a9ecfcb-cc49-4025-b325-a9a6b30cbd6c  Sonusingh Rajput
# 1  e3f5fa7e-8d82-4d88-a821-f65a50d2a154    Ahamed Thameez
# 2  da0298b8-f353-4902-b133-23c20e5e7ee3            atilla
# 3  28fd3d35-f739-4a8b-af7b-8c86e3e4d3f0      Mahek Shaikh
# 4  137123cf-74d0-4779-8226-31d108d2dbe9     Gautam Panwar
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                      content  score  thumbsUpCount reviewCreatedVersion  \
# 0                        👍👍👍      5              0                 None
# 1                       Good      5              0            8.7.0.297
# 2  This game is really good.      5              0                 None
# ...

# %%
ludo.shape
# Out:
# (1000, 11)

# %%
ludo.tail()
# Out:
#                                  reviewId         userName  \
# 995  5f1bc462-1d6e-4424-9cbb-d87b0367279b       Ramjan Ali
# 996  fd6a8db9-bdb0-43d6-abbb-29ed28bdc54b      Aman Grewal
# 997  f75fc2b3-400a-4aca-b551-dacc37dba40b  Shankar Vaisnov
# 998  c3c61b45-9598-496c-9009-ace5e414004a   Md Nadim Husen
# 999  b837eca0-9ee8-46ae-998d-b849ae451704        Raju khan
#
#                                              userImage              content  \
# 995  https://play-lh.googleusercontent.com/a/ACg8oc...                  😍😍😍
# 996  https://play-lh.googleusercontent.com/a/ACg8oc...    Bahut badhiya hai
# 997  https://play-lh.googleusercontent.com/a/ACg8oc...                Komal
# 998  https://play-lh.googleusercontent.com/a/ACg8oc...                 Good
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...  The top 1 best game
#
#      score  thumbsUpCount reviewCreatedVersion                  at  \
# 995      5              0                 None 2024-07-29 13:44:10
# ...

# %%
ludo.isna().sum()
# Out:
# reviewId                  0
# userName                  0
# userImage                 0
# content                   0
# score                     0
# thumbsUpCount             0
# reviewCreatedVersion    648
# at                        0
# replyContent            504
# repliedAt               504
# appVersion              648
# dtype: int64

# %%
ludo.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion'],
#       dtype='object')

# %%
ludo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              1000 non-null   object
#  1   userName              1000 non-null   object
#  2   userImage             1000 non-null   object
#  3   content               1000 non-null   object
#  4   score                 1000 non-null   int64
#  5   thumbsUpCount         1000 non-null   int64
#  6   reviewCreatedVersion  352 non-null    object
#  7   at                    1000 non-null   datetime64[ns]
#  8   replyContent          496 non-null    object
#  9   repliedAt             496 non-null    datetime64[ns]
#  10  appVersion            352 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 86.1+ KB

# %%
from IPython.display import HTML
import base64
def create_download_link( data, title = "Download CSV file", filename = "ludo.csv"):  
    csv = ludo.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(ludo)
# Out:
# <a download="ludo.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %% [markdown]
# # _____________________________________________________
#
# ### Mohammed Musthafa
